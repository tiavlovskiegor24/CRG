# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %run ~/CRG/scripts/hic_contact_decay.py
Contact_Decay_Feature("contacts_decay_Jurkat_50kb")
# Out:
# Processing chr1
# chr1 finished
# Processing chr10
# chr10 finished
# Processing chr11
# chr11 finished
# Processing chr12
# chr12 finished
# Processing chr13
# chr13 finished
# Processing chr14
# chr14 finished
# Processing chr15
# chr15 finished
# Processing chr16
# chr16 finished
# Processing chr17
# chr17 finished
# Processing chr18
# chr18 finished
# Processing chr19
# chr19 finished
# Processing chr2
# chr2 finished
# Processing chr20
# chr20 finished
# Processing chr21
# chr21 finished
# Processing chr22
# chr22 finished
# Processing chr3
# chr3 finished
# Processing chr4
# chr4 finished
# Processing chr5
# chr5 finished
# Processing chr6
# chr6 finished
# Processing chr7
# chr7 finished
# Processing chr8
# chr8 finished
# Processing chr9
# chr9 finished
# Processing chrM
# Processing chrX
# chrX finished
# Processing chrY
# chrY finished
# Everything is finished

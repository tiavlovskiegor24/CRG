# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %run ~/CRG/scripts/GMFPT_theory.py
Compute_GMFPT_Feature("gmfpt_feature_Jurkat_50kb")
# Out:
# Processing chr1
# Matrix shape: (4986, 4986)
# Density 0.27
# Density 	before:0.273
# 		after 0.123
# Computing Eigenvectors of Laplacian
# Time taken: 27.821
# Computing GMFPT
# chr1 finished
# Processing chr10
# Matrix shape: (2711, 2711)
# Density 0.46
# Density 	before:0.458
# 		after 0.240
# Computing Eigenvectors of Laplacian
# Time taken: 4.203
# Computing GMFPT
# chr10 finished
# Processing chr11
# Matrix shape: (2701, 2701)
# Density 0.46
# Density 	before:0.463
# 		after 0.245
# Computing Eigenvectors of Laplacian
# Time taken: 4.683
# Computing GMFPT
# chr11 finished
# Processing chr12
# Matrix shape: (2678, 2678)
# Density 0.45
# Density 	before:0.454
# 		after 0.230
# Computing Eigenvectors of Laplacian
# Time taken: 4.121
# Computing GMFPT
# chr12 finished
# Processing chr13
# Matrix shape: (2304, 2304)
# Density 0.40
# Density 	before:0.400
# 		after 0.218
# Computing Eigenvectors of Laplacian
# Time taken: 1.947
# Computing GMFPT
# chr13 finished
# Processing chr14
# ...
